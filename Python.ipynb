# %% [markdown]
# <a href="https://colab.research.google.com/github/jose07099/python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
("Elaborar um sistema de aprovação de estudantes;")

("Nota >= 7 aprovado;")
("Nota <7 e >4 recuperação;")
("Nota < 4 reprovado;")

("De o seu melhor")
# Out:
# 'De o seu melhor'

# %%
("• Livro de ficção: 10 pontos")
("• Livro de não-ficção: 8 pontos")
("• Livro infantil: 6 pontos")

("Rodrigo leu um livro de cada categoria. Agora ele quer saber quantos pontos acumulou com sua leitura.")
("Nosso objetivo é criar um programa em Python que:")

("• Armazene a pontuação de cada categoria de livro em uma variável.")
("• Calcule o total de pontos acumulados por Rodrigo.")
("• Mostre na tela o total de pontos acumulados por Rodrigo.")
# Out:
# '• Mostre na tela o total de pontos acumulados por Rodrigo.'

# %%
("Printi")
("o Luís não presta atenção nas aulas")
# Out:
# 'o Luís não presta atenção nas aulas'

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
    # Calcula a idade do terceiro filho
    idade_filho3 = idade_monica - idade_filho1 - idade_filho2

    # Utiliza a função max para calcular a maior idade entre os 3 filhos
    idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)

    # Retorna a idade do terceiro filho e a idade do filho mais velho
    return idade_filho3, idade_maxima


# Chamada da função e exibição do resultado
idade_filho3, idade_mais_velho = calcula_idade_maior(68, 12, 30)
print(f"Idade do terceiro filho: {idade_filho3}")
print(f"Idade do filho mais velho: {idade_mais_velho}")
# Out:
# Idade do terceiro filho: 26
# Idade do filho mais velho: 30

# %%
p = int(input("Digite a posição da porta P (0 ou 1): "))
r = int(input("Digite a posição da porta R (0 ou 1): "))
q = int(input("Digite a posição da porta Q (0 ou 1): "))

if p == 0:
    print("Seguirá pelo caminho: C")
elif p == 1 and r == 1 and q == 0:
    print("Seguirá pelo caminho: A")
elif p == 1 and r == 1 and q == 1:
    print("Seguirá pelo caminho: Q")
elif p == 1 and r == 0:
    print("Seguirá pelo caminho: B")
else:
    print("Seguirá pelo caminho: B")

# %%
# Pontuação por categoria
ficcao = 10
nficcao = 8
infantil = 6

# Rodrigo leu um livro de cada tipo
livros_lidos = 3

# Calcula o total de pontos acumulados
pontos_totais = ficcao + nficcao + infantil

# Mostra os resultados
print(f"Total de livros lidos por Rodrigo: {livros_lidos}")
print(f"Total de pontos acumulados por Rodrigo: {pontos_totais}")
# Out:
# Total de livros lidos por Rodrigo: 3
# Total de pontos acumulados por Rodrigo: 24

# %%
print("Everything can change if you learn to change")

solution = "How could I change, if I have no clue?"

print(solution, "I already said it!")
print(f"{solution} I already said it!!!")
# Out:
# Everything can change if you learn to change
# How could I change, if I have no clue? I already said it!
# How could I change, if I have no clue? I already said it!!!

# %%
def maior_livro(paginas):
    # A função recebe uma lista de números e retorna o maior deles
    return max(paginas)


# Programa principal
print("Descubra qual livro tem mais páginas!")

# Coleta dos dados
livros = []
for i in range(1, 6):
    num_paginas = int(input(f"Digite a quantidade de páginas do livro {i}: "))
    livros.append(num_paginas)

# Chama a função e mostra o resultado
maior = maior_livro(livros)
print(f"\nO livro com mais páginas tem {maior} páginas.")
# Out:
# Descubra qual livro tem mais páginas!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-875210282.py in <cell line: 0>()
#      10 livros = []
#      11 for i in range(1, 6):
# ---> 12     num_paginas = int(input(f"Digite a quantidade de páginas do livro {i}: "))
#      13     livros.append(num_paginas)
#      14
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Entrada de dados
total_figurinhas = int(input("Digite o total de figurinhas: "))
numero_amigos = int(input("Digite o número de amigos de João (sem contar o João): "))

# Cálculo
x = total_figurinhas // (numero_amigos + 2)  # Figurinhas por amigo
joao = 2 * x  # João recebe o dobro

# Saída
print(f"Cada amigo recebeu {x} figurinhas.")
print(f"João recebeu {joao} figurinhas.")
